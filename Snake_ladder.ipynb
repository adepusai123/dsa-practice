# %% [markdown]
# 1. Board – Represents the game board with cells, snakes, and ladders.
# 2. Cell – Represents a position on the board.
# 3. Snake – Moves a player down when landed on.
# 4. Ladder – Moves a player up when landed on.
# 5. Player – Represents a player with a name and position.
# 6. Dice – Rolls a random number (1-6).
# 7. Game – Controls the game loop and manages players.

# %%
from collections import deque
import random

class Jump:
    # indicates snake & ladder
    def __init__(self, start, end):
        self.start = start
        self.end = end

class Player:
    def __init__(self, name):
        self.name = name
        self.position = 0

class Dice:
    @staticmethod
    def roll():
        return random.randint(1,6)

class Board:
    def __init__(self, size):
        self.size = size
        self.jumps = {} # maps start position to Jump (snake/Ladder)

    def add_jump(self, start, end):
        self.jumps[start] = Jump(start, end)

    def get_new_position(self, position):
        return self.jumps[position].end if position in self.jumps else position

# main controller for this problem
class Game:
    def __init__(self, board_size):
        self.board = Board(board_size)
        self.dice = Dice()
        self.players = deque() #queue to maintain players turns

    def add_player(self,name):
        self.players.append(Player(name))

    def add_snake(self, start, end):
        self.board.add_jump(start, end)

    def add_ladder(self, start, end):
        self.board.add_jump(start, end)

    def start(self):
        while True:
            player = self.players.popleft() # get the current player
            roll = self.dice.roll()
            new_position = player.position + roll

            if new_position > self.board.size:
                print(f"{player.name} rolled {roll} but cannot move beyond {self.board.size}.")
                self.players.append(player)
                continue # skip turn 

            new_position = self.board.get_new_position(new_position)
            player.position  = new_position 
            
            print(f"{player.name} rolled {roll} and moved to {new_position}")

            if new_position == self.board.size:
                print(f"{player.name} is wins the game")
                break

            self.players.append(player)

# %%
game = Game(100)

# %%
# Adding players
game.add_player("Alice")
game.add_player("Bob")

# Adding snakes (downward movement)
game.add_snake(25, 5)
game.add_snake(50, 30)
game.add_snake(75, 35)
game.add_snake(90, 45)
game.add_snake(99, 10)

# Adding ladders (upward movement)
game.add_ladder(2, 15)
game.add_ladder(10, 25)
game.add_ladder(40, 60)
game.add_ladder(55, 75)
game.add_ladder(80, 95)

# Start game
game.start()
# Out:
# Alice rolled 1 and moved to 11
# Alice rolled 1 and moved to 1
# Bob rolled 5 and moved to 5
# Alice rolled 4 and moved to 15
# Alice rolled 5 and moved to 6
# Bob rolled 1 and moved to 6
# Alice rolled 5 and moved to 20
# Alice rolled 2 and moved to 8
# Bob rolled 2 and moved to 8
# Alice rolled 5 and moved to 5
# Alice rolled 5 and moved to 13
# Bob rolled 5 and moved to 13
# Alice rolled 5 and moved to 25
# Alice rolled 2 and moved to 15
# Bob rolled 4 and moved to 17
# Alice rolled 5 and moved to 30
# Alice rolled 1 and moved to 16
# Bob rolled 5 and moved to 22
# Alice rolled 2 and moved to 32
# Alice rolled 2 and moved to 18
# Bob rolled 2 and moved to 24
# Alice rolled 6 and moved to 38
# Alice rolled 6 and moved to 24
# Bob rolled 4 and moved to 28
# Alice rolled 2 and moved to 60
# Alice rolled 4 and moved to 28
# Bob rolled 3 and moved to 31
# Alice rolled 5 and moved to 65
# Alice rolled 2 and moved to 30
# Bob rolled 2 and moved to 33
# Alice rolled 1 and moved to 66
# Alice rolled 1 and moved to 31
# Bob rolled 6 and moved to 39
# Alice rolled 3 and moved to 69
# Alice rolled 1 and moved to 32
# Bob rolled 5 and moved to 44
# Alice rolled 2 and moved to 71
# Alice rolled 2 and moved to 34
# Bob rolled 5 and moved to 49
# Alice rolled 5 and moved to 76
# Alice rolled 5 and moved to 39
# Bob rolled 2 and moved to 51
# Alice rolled 1 and moved to 77
# Alice rolled 4 and moved to 43
# Bob rolled 6 and moved to 57
# Alice rolled 4 and moved to 81
# Alice rolled 1 and moved to 44
# Bob rolled 4 and moved to 61
# Alice rolled 5 and moved to 86
# Alice rolled 1 and moved to 45
# Bob rolled 1 and moved to 62
# Alice rolled 3 and moved to 89
# Alice rolled 2 and moved to 47
# Bob rolled 2 and moved to 64
# Alice rolled 1 and moved to 45
# Alice rolled 6 and moved to 53
# Bob rolled 5 and moved to 69
# Alice rolled 6 and moved to 51
# Alice rolled 4 and moved to 57
# Bob rolled 6 and moved to 35
# Alice rolled 5 and moved to 56
# Alice rolled 5 and moved to 62
# Bob rolled 1 and moved to 36
# Alice rolled 5 and moved to 61
# Alice rolled 5 and moved to 67
# Bob rolled 1 and moved to 37
# Alice rolled 6 and moved to 67
# Alice rolled 1 and moved to 68
# Bob rolled 2 and moved to 39
# Alice rolled 2 and moved to 69
# Alice rolled 1 and moved to 69
# Bob rolled 1 and moved to 60
# Alice rolled 3 and moved to 72
# Alice rolled 1 and moved to 70
# Bob rolled 1 and moved to 61
# Alice rolled 4 and moved to 76
# Alice rolled 6 and moved to 76
# Bob rolled 2 and moved to 63
# Alice rolled 6 and moved to 82
# Alice rolled 3 and moved to 79
# Bob rolled 6 and moved to 69
# Alice rolled 2 and moved to 84
# Alice rolled 6 and moved to 85
# Bob rolled 5 and moved to 74
# Alice rolled 1 and moved to 85
# Alice rolled 2 and moved to 87
# Bob rolled 5 and moved to 79
# Alice rolled 2 and moved to 87
# Alice rolled 4 and moved to 91
# Bob rolled 5 and moved to 84
# Alice rolled 5 and moved to 92
# Alice rolled 6 and moved to 97
# Bob rolled 3 and moved to 87
# Alice rolled 5 and moved to 97
# Alice rolled 4 but cannot move beyond 100.
# Bob rolled 1 and moved to 88
# Alice rolled 1 and moved to 98
# Alice rolled 4 but cannot move beyond 100.
# Bob rolled 6 and moved to 94
# Alice rolled 1 and moved to 10
# Alice rolled 1 and moved to 98
# Bob rolled 1 and moved to 95
# Alice rolled 6 and moved to 16
# Alice rolled 2 and moved to 100
# Alice is wins the game
